# %%
import vectorbt as vbt

# %%
dados = vbt.BinanceData.download('BTCBRL', start='2022-01-25', interval='1m').get()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\dateparser\date_parser.py:35: PytzUsageWarning:
#
# The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
# 0it [00:00, ?it/s]

# %%
dados
# Out:
#                                Open      High       Low     Close   Volume  \
# Open time
# 2022-01-25 03:00:00+00:00  201600.0  201600.0  201490.0  201490.0  0.14343
# 2022-01-25 03:01:00+00:00  201350.0  201366.0  201346.0  201354.0  0.02035
# 2022-01-25 03:02:00+00:00  201365.0  201370.0  201200.0  201227.0  0.06968
# 2022-01-25 03:03:00+00:00  201080.0  201315.0  201080.0  201204.0  0.00807
# 2022-01-25 03:04:00+00:00  201111.0  201228.0  201012.0  201111.0  0.02358
# ...                             ...       ...       ...       ...      ...
# 2022-01-26 18:48:00+00:00  205811.0  205904.0  205672.0  205904.0  0.14831
# 2022-01-26 18:49:00+00:00  205903.0  205928.0  205696.0  205913.0  0.07267
# 2022-01-26 18:50:00+00:00  205756.0  206018.0  205756.0  206018.0  0.10949
# 2022-01-26 18:51:00+00:00  206106.0  206314.0  206056.0  206314.0  0.33332
# 2022-01-26 18:52:00+00:00  206462.0  206462.0  206344.0  206344.0  0.09090
#
# ...

# %%
prices = dados['Close'] 
media_rapida = vbt.MA.run(prices, 15)
media_lenta = vbt.MA.run(prices, 60)

# %%
entradas = media_rapida.ma_crossed_above(media_lenta)
saidas = media_rapida.ma_crossed_below(media_lenta)

# %%
pf = vbt.Portfolio.from_signals(prices, entradas, saidas)

# %%
pf.plot().show()
# Out:
# <div>                            <div id="cc4e9cfe-c1b1-4d68-9f42-aebf54d39732" class="plotly-graph-div" style="height:960px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc4e9cfe-c1b1-4d68-9f42-aebf54d39732")) {                    Plotly.newPlot(                        "cc4e9cfe-c1b1-4d68-9f42-aebf54d39732",                        [{"line":{"color":"#1f77b4"},"name":"Close","showlegend":true,"x":["2022-01-25T03:00:00+00:00","2022-01-25T03:01:00+00:00","2022-01-25T03:02:00+00:00","2022-01-25T03:03:00+00:00","2022-01-25T03:04:00+00:00","2022-01-25T03:05:00+00:00","2022-01-25T03:06:00+00:00","2022-01-25T03:07:00+00:00","2022-01-25T03:08:00+00:00","2022-01-25T03:09:00+00:00","2022-01-25T03:10:00+00:00","2022-01-25T03:11:00+00:00","2022-01-25T03:12:00+00:00","2022-01-25T03:13:00+00:00","2022-01
# ...

# %%
pf.stats()
# Out:
# Start                         2022-01-25 03:00:00+00:00
# End                           2022-01-26 18:52:00+00:00
# Period                                  1 days 15:53:00
# Start Value                                       100.0
# End Value                                    102.306704
# Total Return [%]                               2.306704
# Benchmark Return [%]                           2.409053
# Max Gross Exposure [%]                            100.0
# Total Fees Paid                                     0.0
# Max Drawdown [%]                               3.510727
# Max Drawdown Duration                   0 days 23:01:00
# Total Trades                                         21
# Total Closed Trades                                  21
# Total Open Trades                                     0
# Open Trade PnL                                      0.0
# Win Rate [%]                                  52.380952
# Best Trade [%]                                 1.187094
# ...
